# %%
import ORE
import numpy as np
import scipy

print("ORE loaded:", ORE)
print("NumPy:", np.__version__)
print("SciPy:", scipy.__version__)
# Out:
# ORE loaded: <module 'ORE' from '/home/jonty/repos/ore/.venv-orepy/lib/python3.12/site-packages/ORE.py'>
# NumPy: 2.5.2
# SciPy: 1.18.1

# %%
xccy_classes = [
    x for x in dir(ORE)
    if "CrossCcy" in x or "CrossCurrency" in x
]

xccy_classes
# Out:
# ['ConstNotionalCrossCurrencyBasisSwapRateHelper',
#  'ConstNotionalCrossCurrencySwapRateHelper',
#  'CrossCcyBasisMtMResetSwap',
#  'CrossCcyBasisMtMResetSwapHelper',
#  'CrossCcyBasisSwap',
#  'CrossCcyBasisSwapConvention',
#  'CrossCcyBasisSwapHelper',
#  'CrossCcyBasisSwapQuote',
#  'CrossCcyFixFloatSwap',
#  'CrossCcyFixFloatSwapConvention',
#  'CrossCcyFixFloatSwapHelper',
#  'CrossCcyFixFloatSwapQuote',
#  'CrossCcySwap',
#  'CrossCcySwapEngine',
#  'CrossCcyYieldCurveSegment',
#  'CrossCurrencySwap',
#  'MtMCrossCurrencyBasisSwapRateHelper',
#  'qleMakeCrossCcyFixFloatSwap']

# %%
help(ORE.ConstNotionalCrossCurrencyBasisSwapRateHelper)
# Out:
# Help on class ConstNotionalCrossCurrencyBasisSwapRateHelper in module ORE:
#
# class ConstNotionalCrossCurrencyBasisSwapRateHelper(RateHelper)
#  |  ConstNotionalCrossCurrencyBasisSwapRateHelper(basis, tenor, fixingDays, calendar, convention, endOfMonth, baseCurrencyIndex, quoteCurrencyIndex, collateralCurve, isFxBaseCurrencyCollateralCurrency, isBasisOnFxBaseCurrencyLeg, paymentFrequency=-1, paymentLag=0)
#  |
#  |  ORE API symbol exposed through SWIG bindings.
#  |
#  |  Method resolution order:
#  |      ConstNotionalCrossCurrencyBasisSwapRateHelper
#  |      RateHelper
#  |      Observable
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, basis, tenor, fixingDays, calendar, convention, endOfMonth, baseCurrencyIndex, quoteCurrencyIndex, collateralCurve, isFxBaseCurrencyCollateralCurrency, isBasisOnFxBaseCurrencyLeg, paymentFrequency=-1, paymentLag=0)
# ...

# %%
help(ORE.CrossCcyBasisSwapHelper)
# Out:
# Help on class CrossCcyBasisSwapHelper in module ORE:
#
# class CrossCcyBasisSwapHelper(RateHelper)
#  |  CrossCcyBasisSwapHelper(spreadQuote, spotFX, settlementDays, settlementCalendar, swapTenor, rollConvention, flatIndex, spreadIndex, flatDiscountCurve, spreadDiscountCurve, flatIndexGiven, spreadIndexGiven, flatDiscountCurveGiven, spreadDiscountCurveGiven, eom=False, flatIsDomestic=True)
#  |
#  |  ORE API symbol exposed through SWIG bindings.
#  |
#  |  Method resolution order:
#  |      CrossCcyBasisSwapHelper
#  |      RateHelper
#  |      Observable
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, spreadQuote, spotFX, settlementDays, settlementCalendar, swapTenor, rollConvention, flatIndex, spreadIndex, flatDiscountCurve, spreadDiscountCurve, flatIndexGiven, spreadIndexGiven, flatDiscountCurveGiven, spreadDiscountCurveGiven, eom=False, flatIsDomestic=True)
# ...

# %%
help(ORE.CrossCcyBasisMtMResetSwapHelper)
# Out:
# Help on class CrossCcyBasisMtMResetSwapHelper in module ORE:
#
# class CrossCcyBasisMtMResetSwapHelper(RateHelper)
#  |  CrossCcyBasisMtMResetSwapHelper(*args)
#  |
#  |  ORE API symbol exposed through SWIG bindings.
#  |
#  |  Method resolution order:
#  |      CrossCcyBasisMtMResetSwapHelper
#  |      RateHelper
#  |      Observable
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, *args)
# ...
